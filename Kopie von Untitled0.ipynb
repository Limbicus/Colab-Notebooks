# %%
# !git clone https://github.com/Limbicus/EGA-handlings
# Out:
# Cloning into 'EGA-handlings'...
# remote: Enumerating objects: 16, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 16 (delta 3), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (16/16), done.

# %%
# !wget https://raw.githubusercontent.com/Limbicus/EGA-handlings/main/processing_ega.ipynb
# %load processing_ega.ipynb
# Out:
# --2022-12-30 07:58:24--  https://raw.githubusercontent.com/Limbicus/EGA-handlings/main/processing_ega.ipynb
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 84351 (82K) [text/plain]
# Saving to: ‘processing_ega.ipynb’
#
# processing_ega.ipyn 100%[===================>]  82.37K  --.-KB/s    in 0.002s
#
# 2022-12-30 07:58:25 (49.8 MB/s) - ‘processing_ega.ipynb’ saved [84351/84351]
