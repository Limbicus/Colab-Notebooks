# %%
# !git clone https://github.com/Limbicus/EGA-handlings.git
# Out:
# Cloning into 'EGA-handlings'...
# remote: Enumerating objects: 16, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 16 (delta 3), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (16/16), done.

# %%
# %cd EGA-handlings
# Out:
# /content/EGA-handlings

# %%
# !pip install -r requirements.txt
# nicht notwendig - viele gehen nicht, da Pfade benutzt werden
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Processing /home/ktietz/src/ci/alabaster_1611921544520/work
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: '/home/ktietz/src/ci/alabaster_1611921544520/work'
